# %%
from __future__ import print_function
import pyWinhook as pyHook

data = {}

def addInput(input):
    if input in data.keys():     # 입력하는 키에 대해서
        data[f"{input}"] += 1    #기존에 입력한 키를 입력한 경우 +1을 추가
    else:
        data[f"{input}"] = 1     #그렇지 않을 경우 새로운 정의를 내림

def OnMouseEvent(event):         #마우스 입력
  addInput(event.MessageName)
  print(event.MessageName)       #마우스 클릭 위치 출력
  print(event.WindowName)        #마우스를 어느 곳에서 출력하는지 인지 및 출력
  print('---')

  # return True to pass the event to other handlers
  # return False to stop the event from propagating
  return True

def OnKeyboardEvent(event):      #키보드 입력
  if event.Key == "G":           #키보드의 "G"키를 눌렀을 때 입력 정보 출력
     print(data)
  print(event.WindowName)        #키를 입력한 경로 출력
  print(event.Key)               #입력한 키 출력
  addInput(event.Key)  
  print('---')

  # return True to pass the event to other handlers
  # return False to stop the event from propagating
  return True

# create the hook mananger
hm = pyHook.HookManager()
# register two callbacks
hm.MouseAllButtonsDown = OnMouseEvent
hm.KeyDown = OnKeyboardEvent

# hook into the mouse and keyboard events
hm.HookMouse()
hm.HookKeyboard()

if __name__ == '__main__':
  import pythoncom
  pythoncom.PumpMessages()
# Out:
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# 3
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# A
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# T
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Down
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# 3
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# A
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# T
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# J
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# T
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# P
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# T
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# J
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# {'mouse left down': 3, 'Space': 22, 'Rshift': 2, '3': 2, 'A': 2, 'K': 2, 'D': 5, 'N': 5, 'T': 4, 'M': 5, 'Z': 1, 'F': 8, 'L': 3, 'R': 4, 'C': 3, 'U': 2, 'Down': 1, 'J': 2, 'S': 1, 'Back': 1, 'H': 1, 'P': 1}
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# G
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# W
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# A
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# W
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# W
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Oem_Comma
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# A
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# 3
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# E
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# 3
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# E
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Hangul
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Capital
# ---
# {'mouse left down': 8, 'Space': 44, 'Rshift': 5, '3': 4, 'A': 4, 'K': 5, 'D': 8, 'N': 6, 'T': 4, 'M': 9, 'Z': 3, 'F': 11, 'L': 12, 'R': 7, 'C': 5, 'U': 4, 'Down': 1, 'J': 2, 'S': 4, 'Back': 4, 'H': 3, 'P': 1, 'G': 1, 'W': 3, 'Oem_Comma': 1, 'Q': 3, 'E': 2, 'Hangul': 1, 'Capital': 1}
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# G
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Capital
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Oem_7
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Left
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Left
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Oem_7
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Right
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Right
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Right
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Left
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Hangul
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# J
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# T
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# E
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# O
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# W
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# J
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# 3
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# M
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# {'mouse left down': 17, 'Space': 59, 'Rshift': 21, '3': 5, 'A': 4, 'K': 5, 'D': 12, 'N': 8, 'T': 5, 'M': 12, 'Z': 6, 'F': 23, 'L': 17, 'R': 10, 'C': 6, 'U': 7, 'Down': 1, 'J': 4, 'S': 5, 'Back': 11, 'H': 6, 'P': 1, 'G': 2, 'W': 4, 'Oem_Comma': 1, 'Q': 7, 'E': 3, 'Hangul': 2, 'Capital': 2, 'Oem_7': 2, 'Left': 3, 'Right': 3, 'O': 1}
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# G
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Back
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# H
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Rshift
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# 3
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# D
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Q
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# {'mouse left down': 19, 'Space': 76, 'Rshift': 28, '3': 6, 'A': 4, 'K': 6, 'D': 15, 'N': 9, 'T': 5, 'M': 12, 'Z': 6, 'F': 27, 'L': 18, 'R': 13, 'C': 7, 'U': 10, 'Down': 1, 'J': 4, 'S': 6, 'Back': 12, 'H': 7, 'P': 1, 'G': 3, 'W': 4, 'Oem_Comma': 1, 'Q': 8, 'E': 3, 'Hangul': 2, 'Capital': 2, 'Oem_7': 2, 'Left': 3, 'Right': 3, 'O': 1}
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# G
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# K
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# S
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Z
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# L
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# Space
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# C
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# N
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# F
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# U
# ---
# 키보드,마우스 감지(수정판) - Jupyter Notebook - Chrome
# R
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---
# mouse left down
# Chrome Legacy Window
# ---

# %%
print(data)
